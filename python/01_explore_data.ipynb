# %%
import pandas as pd

# %%
# Load airline data
airline_sample_df = pd.read_csv(
    "data/raw/airline.csv",
    encoding="latin1",
    engine="python",
    nrows=100_000
)

# Load carriers lookup
carriers_df = pd.read_csv("data/raw/carriers.csv")

# %%
airline_sample_df.head()
# Out:
#    ActualElapsedTime  AirTime  ArrDelay  ArrTime  CRSArrTime  CRSDepTime  \
# 0               53.0     32.0      -8.0   1642.0        1650        1545
# 1              164.0    155.0     -11.0   1754.0        1805        1610
# 2               60.0      NaN      15.0   2005.0        1950        1850
# 3               51.0      NaN      -5.0   1818.0        1823        1728
# 4               45.0     29.0       2.0   1120.0        1118        1030
#
#    CRSElapsedTime CancellationCode  Cancelled  CarrierDelay  ...  Month  \
# 0            65.0              NaN          0           NaN  ...     10
# 1           175.0              NaN          0           NaN  ...     12
# 2            60.0              NaN          0           NaN  ...     12
# 3            55.0              NaN          0           NaN  ...      9
# 4            48.0              NaN          0           0.0  ...      6
#
#    NASDelay  Origin  SecurityDelay TailNum  TaxiIn  TaxiOut  UniqueCarrier  \
# 0       NaN     DCA            NaN  N443US     7.0     14.0             US
# 1       NaN     MCO            NaN    N755     2.0      7.0             WN
# 2       NaN     ATL            NaN     NaN     NaN      NaN             DL
# 3       NaN     MEM            NaN     NaN     NaN      NaN             AA
# 4       0.0     CVG            0.0  N785CA     3.0     13.0             OH
#
#    WeatherDelay  Year
# 0           NaN  2002
# 1           NaN  1999
# 2           NaN  1993
# 3           NaN  1989
# 4           0.0  2006
#
# [5 rows x 29 columns]

# %%
airline_sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ActualElapsedTime  97855 non-null   float64
#  1   AirTime            67903 non-null   float64
#  2   ArrDelay           97855 non-null   float64
#  3   ArrTime            97858 non-null   float64
#  4   CRSArrTime         100000 non-null  int64
#  5   CRSDepTime         100000 non-null  int64
#  6   CRSElapsedTime     99976 non-null   float64
#  7   CancellationCode   612 non-null     object
#  8   Cancelled          100000 non-null  int64
#  9   CarrierDelay       27443 non-null   float64
#  10  DayOfWeek          100000 non-null  int64
#  11  DayofMonth         100000 non-null  int64
#  12  DepDelay           98111 non-null   float64
#  13  DepTime            98111 non-null   float64
#  14  Dest               100000 non-null  object
#  15  Distance           99820 non-null   float64
#  16  Diverted           100000 non-null  int64
#  17  FlightNum          100000 non-null  int64
#  18  LateAircraftDelay  27443 non-null   float64
#  19  Month              100000 non-null  int64
#  20  NASDelay           27443 non-null   float64
#  21  Origin             100000 non-null  object
#  22  SecurityDelay      27443 non-null   float64
#  23  TailNum            69490 non-null   object
#  24  TaxiIn             69471 non-null   float64
#  25  TaxiOut            69485 non-null   float64
#  26  UniqueCarrier      100000 non-null  object
#  27  WeatherDelay       27443 non-null   float64
#  28  Year               100000 non-null  int64
# dtypes: float64(15), int64(9), object(5)
# memory usage: 22.1+ MB

# %%
airline_sample_df.columns
# Out:
# Index(['ActualElapsedTime', 'AirTime', 'ArrDelay', 'ArrTime', 'CRSArrTime',
#        'CRSDepTime', 'CRSElapsedTime', 'CancellationCode', 'Cancelled',
#        'CarrierDelay', 'DayOfWeek', 'DayofMonth', 'DepDelay', 'DepTime',
#        'Dest', 'Distance', 'Diverted', 'FlightNum', 'LateAircraftDelay',
#        'Month', 'NASDelay', 'Origin', 'SecurityDelay', 'TailNum', 'TaxiIn',
#        'TaxiOut', 'UniqueCarrier', 'WeatherDelay', 'Year'],
#       dtype='object')

# %%
df = airline_sample_df.copy()

# %%
# Fix Column Names

df.columns = (
    df.columns
      .str.strip()
      .str.lower()
)

# %%
# Handle Missing Delay Values
delay_cols = ["depdelay", "arrdelay"]

for col in delay_cols:
    df[col] = df[col].fillna(0)

# %%
# Convert Flags to Clean Integers

df["cancelled"] = df["cancelled"].astype(int)
df["diverted"] = df["diverted"].astype(int)

# %%
# Create a Proper Flight Date

df["flight_date"] = pd.to_datetime(
    dict(
        year=df["year"],
        month=df["month"],
        day=df["dayofmonth"]
    )
)

# %%
# Standardize Airport & Airline Codes

df["origin"] = df["origin"].str.upper().str.strip()
df["dest"] = df["dest"].str.upper().str.strip()
df["uniquecarrier"] = df["uniquecarrier"].str.upper().str.strip()

# %%
# Remove Obviously Invalid Rows

df = df[df["distance"] > 0]

# %%
# Keep Only SQL-Relevant Columns

final_cols = [
    "flight_date",
    "year",
    "month",
    "dayofmonth",
    "dayofweek",
    "uniquecarrier",
    "flightnum",
    "origin",
    "dest",
    "distance",
    "depdelay",
    "arrdelay",
    "cancelled",
    "diverted"
]

df = df[final_cols]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99820 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   flight_date    99820 non-null  datetime64[ns]
#  1   year           99820 non-null  int64
#  2   month          99820 non-null  int64
#  3   dayofmonth     99820 non-null  int64
#  4   dayofweek      99820 non-null  int64
#  5   uniquecarrier  99820 non-null  object
#  6   flightnum      99820 non-null  int64
#  7   origin         99820 non-null  object
#  8   dest           99820 non-null  object
#  9   distance       99820 non-null  float64
#  10  depdelay       99820 non-null  float64
#  11  arrdelay       99820 non-null  float64
#  12  cancelled      99820 non-null  int64
#  13  diverted       99820 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(3)
# memory usage: 11.4+ MB

# %%
df.head()
# Out:
#   flight_date  year  month  dayofmonth  dayofweek uniquecarrier  flightnum  \
# 0  2002-10-10  2002     10          10          4            US        209
# 1  1999-12-02  1999     12           2          4            WN        109
# 2  1993-12-10  1993     12          10          5            DL       1276
# 3  1989-09-28  1989      9          28          4            AA        961
# 4  2006-06-19  2006      6          19          1            OH       5873
#
#   origin dest  distance  depdelay  arrdelay  cancelled  diverted
# 0    DCA  PIT     205.0       4.0      -8.0          0         0
# 1    MCO  MCI    1072.0       0.0     -11.0          0         0
# 2    ATL  CLT     227.0      15.0      15.0          0         0
# 3    MEM  BNA     200.0      -1.0      -5.0          0         0
# 4    CVG  CMH     116.0       5.0       2.0          0         0

# %%
df.describe()
# Out:
#                          flight_date          year         month  \
# count                          99820  99820.000000  99820.000000
# mean   1999-02-01 06:39:14.317772032   1998.583851      6.555991
# min              1987-10-01 00:00:00   1987.000000      1.000000
# 25%              1993-10-05 18:00:00   1993.000000      4.000000
# 50%              1999-06-30 00:00:00   1999.000000      7.000000
# 75%              2004-08-31 00:00:00   2004.000000     10.000000
# max              2008-12-31 00:00:00   2008.000000     12.000000
# std                              NaN      6.223100      3.442044
#
#          dayofmonth     dayofweek     flightnum      distance      depdelay  \
# count  99820.000000  99820.000000  99820.000000  99820.000000  99820.000000
# mean      15.742837      3.938750   1362.792827    700.588229      7.970156
# min        1.000000      1.000000      1.000000     11.000000    -64.000000
# 25%        8.000000      2.000000    448.000000    306.000000     -2.000000
# 50%       16.000000      4.000000    939.000000    543.000000      0.000000
# 75%       23.000000      6.000000   1709.000000    936.000000      6.000000
# max       31.000000      7.000000   9578.000000   4962.000000   1197.000000
# std        8.800028      1.990016   1402.798253    551.375698     27.495780
#
#            arrdelay     cancelled      diverted
# count  99820.000000  99820.000000  99820.000000
# mean       6.990573      0.018924      0.002555
# min    -1252.000000      0.000000      0.000000
# 25%       -7.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%       11.000000      0.000000      0.000000
# max     1183.000000      1.000000      1.000000
# std       30.995066      0.136258      0.050479
